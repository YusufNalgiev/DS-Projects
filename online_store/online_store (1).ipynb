# %% [markdown]
# # Персонализация предложений в интернет-магазине

# %% [markdown]
# Интернет-магазин «В один клик» продаёт разные товары: для детей, для дома, мелкую бытовую технику, косметику и даже продукты. Отчёт магазина за прошлый период показал, что активность покупателей начала снижаться. Привлекать новых клиентов уже не так эффективно: о магазине и так знает большая часть целевой аудитории. Возможный выход — удерживать активность постоянных клиентов. Сделать это можно с помощью персонализированных предложений.
# «В один клик» — современная компания, поэтому её руководство не хочет принимать решения просто так — только на основе анализа данных и бизнес-моделирования. У компании есть небольшой отдел цифровых технологий, и вам предстоит побыть в роли стажёра в этом отделе.
# Итак, вашему отделу поручили разработать решение, которое позволит персонализировать предложения постоянным клиентам, чтобы увеличить их покупательскую активность.

# %% [markdown]
# # Описание данных

# %% [markdown]
# `market_file.csv`
#
# Таблица, которая содержит данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении.
#
# - `id` — номер покупателя в корпоративной базе данных.
# - `Покупательская активность` — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - `Тип сервиса` — уровень сервиса, например «премиум» и «стандарт».
# - `Разрешить сообщать` — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - `Маркет_актив_6_мес` — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - `Маркет_актив_тек_мес` — количество маркетинговых коммуникаций в текущем месяце.
# - `Длительность` — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - `Акционные_покупки` — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - `Популярная_категория` — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - `Средний_просмотр_категорий_за_визит` — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - `Неоплаченные_продукты_штук_квартал` — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - `Ошибка_сервиса` — число сбоев, которые коснулись покупателя во время посещения сайта.
# - `Страниц_за_визит` — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.

# %% [markdown]
# `market_money.csv`
#
# Таблица с данными о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом.
#
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксирована выручка. Например, `'текущий_месяц'` или `'предыдущий_месяц'`.
# - `Выручка` — сумма выручки за период.

# %% [markdown]
# `market_time.csv`
#
# Таблица с данными о времени (в минутах), которое покупатель провёл на сайте в течение периода.
#
# - `id` — номер покупателя в корпоративной базе данных.
# - `Период` — название периода, во время которого зафиксировано общее время.
# - `минут` — значение времени, проведённого на сайте, в минутах.

# %% [markdown]
# `money.csv`
#
# Таблица с данными о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю.
#
# - `id` — номер покупателя в корпоративной базе данных.
# - `Прибыль` — значение прибыли.

# %% [markdown]
# # План работы

# %% [markdown]
# **Шаг 1. Загрузка данных**
#
# 1.1 Загрузите данные. Файлы `market_file.csv`, `market_money.csv`, `market_time.csv`, `money.csv` доступны по ссылкам в описании данных или через пути к ним:
#
# - `/datasets/market_file.csv`
# - `/datasets/market_money.csv`
# - `/datasets/market_time.csv`
# - `/datasets/money.csv`
#
# Обратите внимание: в некоторых файлах разделитель значений — точка с запятой, а разделитель десятичных значений — запятая.
#
# 1.2 Проверьте, что данные в таблицах соответствуют описанию. Исследованием и объединением данных вы займётесь позже.
#
# **Шаг 2. Предобработка данных**
#
# Проведите необходимую предобработку данных. Названия столбцов можно оставить кириллическими.
#
# **Шаг 3. Исследовательский анализ данных**
#
# Проведите исследовательский анализ данных из каждой таблицы. Отберите клиентов с покупательской активностью не менее трёх месяцев, то есть таких, которые что-либо покупали в этот период. Оформите выводы по результатам шага.
#
# **Шаг 4. Объединение таблиц**
#
# 4.1 Объедините таблицы `market_file.csv`, `market_money.csv`, `market_time.csv`. Данные о прибыли из файла `money.csv` при моделировании вам не понадобятся.
#
# 4.2 Учитывайте, что данные о выручке и времени на сайте находятся в одном столбце для всех периодов. В итоговой таблице сделайте отдельный столбец для каждого периода.
#
# **Шаг 5. Корреляционный анализ**
#
# Проведите корреляционный анализ признаков в количественной шкале в итоговой таблице для моделирования. Сделайте выводы о мультиколлинеарности и при необходимости устраните её.
#
# **Шаг 6. Использование пайплайнов**
#
# Примените все изученные модели. Для этого используйте пайплайны.
#
# 6.1 Во время подготовки данных используйте `ColumnTransformer`. Количественные и категориальные признаки обработайте в пайплайне раздельно. Для кодирования категориальных признаков используйте как минимум два кодировщика, для масштабирования количественных — как минимум два скейлера.
#
# Напоминаем, что для каждой модели можно подготовить данные с разным кодированием и масштабированием.
#
# 6.2 Обучите четыре модели: `KNeighborsClassifier()`, `DecisionTreeClassifier()`, `LogisticRegression()` и  `SVC()`. Для каждой из них подберите как минимум один гиперпараметр. Выберите подходящую для задачи метрику, аргументируйте свой выбор. Используйте эту метрику при подборе гиперпараметров.
#
# 6.3 Выберите лучшую модель, используя заданную метрику. Для этого примените одну из стратегий:
#
# - использовать пайплайны и инструменты подбора гиперпараметров для каждой модели отдельно, чтобы выбрать лучшую модель самостоятельно;
# - использовать один общий пайплайн для всех моделей и инструмент подбора гиперпараметров, который вернёт вам лучшую модель.
#
# **Шаг 7. Анализ важности признаков**
#
# 7.1 Оцените важность признаков для лучшей модели и постройте график важности с помощью метода SHAP.
#
# 7.2 Сделайте выводы о значимости признаков:
#
# - какие признаки мало значимы для модели;
# - какие признаки сильнее всего влияют на целевой признак;
# - как можно использовать эти наблюдения при моделировании и принятии бизнес-решений.
#
# **Шаг 8. Сегментация покупателей**
#
# 8.1 Выполните сегментацию покупателей. Используйте результаты моделирования и данные о прибыльности покупателей.
#
# 8.2 Выберите группу покупателей и предложите, как увеличить её покупательскую активность:
#
# - Проведите графическое и аналитическое исследование группы покупателей.
# - Сделайте предложения по работе с сегментом для увеличения покупательской активности.
#
# 8.3 Сделайте выводы о сегментах:
#
# - какой сегмент вы взяли для дополнительного исследования,
# - какие предложения вы сделали и почему.
#
# **Шаг 9. Общий вывод**
#
# Сделайте общий вывод:
#
# - опишите задачу;
# - опишите исходные данные и проведённую предобработку;
# - напишите, что вы сделали для поиска лучшей модели;
# - укажите лучшую модель;
# - добавьте выводы и дополнительные предложения для выбранного сегмента покупателей.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %% [markdown]
# ## Загрузка данных

# %%
# !pip install phik
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 5.3 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade  scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 29.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
# импортируем необходимые библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import (
OneHotEncoder,
OrdinalEncoder,
StandardScaler,
MinMaxScaler,
PolynomialFeatures,
LabelEncoder)
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.inspection import permutation_importance

import phik
import shap
import time

# %%
market_file = pd.read_csv('https://code.s3.yandex.net/datasets/market_file.csv', sep=',')
market_money = pd.read_csv('https://code.s3.yandex.net/datasets/market_money.csv', sep=',')
market_time = pd.read_csv('https://code.s3.yandex.net/datasets/market_time.csv', sep=',')
money = pd.read_csv('https://code.s3.yandex.net/datasets/money.csv', sep=';', decimal=',')

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
market_file.head()
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# ...

# %%
market_money.head()
# Out:
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6

# %%
market_time.head()
# Out:
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13

# %%
money.head()
# Out:
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21

# %% [markdown]
# **Промежуточный вывод:**
# Четыре датасета:
# - `market_file` (1300 строк, 12 столбцов)
# - `market_money` (3900 строк, 3 столбца)
# - `market_time` (2600 строк, 3 столбца)
# - `money` (1300 строк, 2 столбца)

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка названий столбцов

# %%
market_file.columns = [x.lower() for x in market_file.columns]
market_time.columns = [x.lower() for x in market_time.columns]
market_money.columns = [x.lower() for x in market_money.columns]
money.columns = [x.lower() for x in money.columns]

# %%
market_file = market_file.rename(columns={
    'покупательская активность': 'покупательская_активность',
    'тип сервиса': 'тип_сервиса',
    'разрешить сообщать': 'разрешить_сообщать'})

# %% [markdown]
# ### Обработка пропусков

# %%
market_file.isna().sum()
# Out:
# id                                     0
# покупательская_активность              0
# тип_сервиса                            0
# разрешить_сообщать                     0
# маркет_актив_6_мес                     0
# маркет_актив_тек_мес                   0
# длительность                           0
# акционные_покупки                      0
# популярная_категория                   0
# средний_просмотр_категорий_за_визит    0
# неоплаченные_продукты_штук_квартал     0
# ошибка_сервиса                         0
# страниц_за_визит                       0
# dtype: int64

# %%
market_time.isna().sum()
# Out:
# id        0
# период    0
# минут     0
# dtype: int64

# %%
market_money.isna().sum()
# Out:
# id         0
# период     0
# выручка    0
# dtype: int64

# %%
money.isna().sum()
# Out:
# id         0
# прибыль    0
# dtype: int64

# %% [markdown]
# Пропусков нет

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Посмотрим на неявные дубликаты**

# %%
for i in market_file.select_dtypes(include=["object_"]):
    print(f'Уникальные значения в столбце {i}:', market_file[i].unique())
# Out:
# Уникальные значения в столбце покупательская_активность: ['Снизилась' 'Прежний уровень']
# Уникальные значения в столбце тип_сервиса: ['премиум' 'стандартт' 'стандарт']
# Уникальные значения в столбце разрешить_сообщать: ['да' 'нет']
# Уникальные значения в столбце популярная_категория: ['Товары для детей' 'Домашний текстиль' 'Косметика и аксесуары'
#  'Техника для красоты и здоровья' 'Кухонная посуда'
#  'Мелкая бытовая техника и электроника']

# %%
market_file = (market_file
    .replace(['стандартт'], 'стандарт', regex=True)
    .replace('Косметика и аксесуары', 'Косметика и аксессуары'))

# %%
for i in market_time.select_dtypes(include=["object_"]):
    print(f'Уникальные значения в столбце {i}:', market_time[i].unique())
# Out:
# Уникальные значения в столбце период: ['текущий_месяц' 'предыдцщий_месяц']

# %%
market_time = (market_time
    .replace(['предыдцщий_месяц'], 'предыдущий_месяц', regex=True))

# %%
for i in market_money.select_dtypes(include=["object_"]):
    print(f'Уникальные значения в столбце "{i}":', market_money[i].unique())
# Out:
# Уникальные значения в столбце "период": ['препредыдущий_месяц' 'текущий_месяц' 'предыдущий_месяц']

# %% [markdown]
# В датасете `money` нет категориальных переменных

# %%
print(f'Количество дубликатов в market_file:',
      market_file.duplicated().sum())
# Out:
# Количество дубликатов в market_file: 0

# %%
print(f'Количество дубликатов в market_time:',
      market_time.duplicated().sum())
# Out:
# Количество дубликатов в market_time: 0

# %%
print(f'Количество дубликатов в market_money:',
      market_money.duplicated().sum())
# Out:
# Количество дубликатов в market_money: 0

# %%
print(f'Количество дубликатов в money:',
      money.duplicated().sum())
# Out:
# Количество дубликатов в money: 0

# %% [markdown]
# Удалим дубликаты в `market_money`

# %%
market_money = market_money.drop_duplicates()

# %% [markdown]
# Все дубликаты выявлены и устранены, названия столбцов переименовали.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Исследуем датасеты по очереди

# %%
market_file.describe().T
# Out:
#                                       count           mean         std  \
# id                                   1300.0  215997.500000  375.421985
# маркет_актив_6_мес                   1300.0       4.253769    1.014814
# маркет_актив_тек_мес                 1300.0       4.011538    0.696868
# длительность                         1300.0     601.898462  249.856289
# акционные_покупки                    1300.0       0.319808    0.249843
# средний_просмотр_категорий_за_визит  1300.0       3.270000    1.355350
# неоплаченные_продукты_штук_квартал   1300.0       2.840000    1.971451
# ошибка_сервиса                       1300.0       4.185385    1.955298
# страниц_за_визит                     1300.0       8.176923    3.978126
#
#                                           min        25%        50%  \
# id                                   215348.0  215672.75  215997.50
# маркет_актив_6_мес                        0.9       3.70       4.20
# ...

# %%
fig, axs = plt.subplots(4, 2, figsize=(17, 23))
plt.suptitle('Гистограммы количественных признаков \'market_file\' ', fontsize=20)

axs[0][0].set_title('Маркет актив 6 месяцев', fontsize=13)
sns.histplot(data=market_file, x='маркет_актив_6_мес', hue='покупательская_активность', ax=axs[0][0], kde=True, bins=20)

axs[0][1].set_title('Маркет актив текущий месяц', fontsize=13)
sns.histplot(data=market_file, x='маркет_актив_тек_мес', hue='покупательская_активность', ax=axs[0][1], kde=True)

axs[1][0].set_title('Длительность', fontsize=13)
sns.histplot(data=market_file, x='длительность', hue='покупательская_активность', ax=axs[1][0], kde=True)

axs[1][1].set_title('Акционные покупки', fontsize=13)
sns.histplot(data=market_file, x='акционные_покупки', hue='покупательская_активность', ax=axs[1][1], kde=True)

axs[2][0].set_title('Средний просмотр категорий за визит', fontsize=13)
sns.histplot(data=market_file, x='средний_просмотр_категорий_за_визит', hue='покупательская_активность', ax=axs[2][0], kde=True)

axs[2][1].set_title('Неоплаченные продукты штук квартал', fontsize=13)
sns.histplot(data=market_file, x='неоплаченные_продукты_штук_квартал', hue='покупательская_активность', ax=axs[2][1], kde=True)

axs[3][0].set_title('Ошибка сервиса', fontsize=13)
sns.histplot(data=market_file, x='ошибка_сервиса', hue='покупательская_активность', ax=axs[3][0], kde=True)

axs[3][1].set_title('Количество страниц за визит', fontsize=13)
sns.histplot(data=market_file, x='страниц_за_визит', hue='покупательская_активность', ax=axs[3][1], kde=True);

# %%
fig, axs = plt.subplots(4, 2, figsize=(15, 20))
plt.suptitle('Ящики с усами', fontsize=20)

axs[0][0].boxplot(market_file['маркет_актив_6_мес'])
axs[0][0].set_title('Маркет актив 6 месяцев', fontsize=15)

axs[0][1].boxplot(market_file['маркет_актив_тек_мес'])
axs[0][1].set_title('Маркет актив текущий месяц', fontsize=15)

axs[1][0].boxplot(market_file['длительность'])
axs[1][0].set_title('Длительность', fontsize=15)

axs[1][1].boxplot(market_file['акционные_покупки'])
axs[1][1].set_title('Акционные покупки', fontsize=12)

axs[2][0].boxplot(market_file['средний_просмотр_категорий_за_визит'])
axs[2][0].set_title('Средний просмотр категорий за визит', fontsize=15)

axs[2][1].boxplot(market_file['неоплаченные_продукты_штук_квартал']);
axs[2][1].set_title('Неоплаченные продукты штук квартал', fontsize=15);

axs[3][0].boxplot(market_file['ошибка_сервиса']);
axs[3][0].set_title('Количество ошибок сервиса', fontsize=15);

axs[3][1].boxplot(market_file['страниц_за_визит']);
axs[3][1].set_title('Количество страниц за визит', fontsize=15);

# %% [markdown]
# Данные в основном распределены близко к нормальному, имеются выбросы у акционных покупок

# %%
(market_file.query('акционные_покупки > 0.5')['акционные_покупки'].count()) / market_file['акционные_покупки'].count() * 100
# Out:
# 12.923076923076923

# %% [markdown]
# Если удалим выбросы акционных покупок, то потеряем 12 % данных

# %%
market_time.describe()
# Out:
#                   id        минут
# count    2600.000000  2600.000000
# mean   215997.500000    13.336154
# std       375.349754     4.080198
# min    215348.000000     4.000000
# 25%    215672.750000    10.000000
# 50%    215997.500000    13.000000
# 75%    216322.250000    16.000000
# max    216647.000000    23.000000

# %%
market_file.select_dtypes(include=["object_"]).columns
# Out:
# Index(['покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'популярная_категория'],
#       dtype='object')

# %%
plt.figure(figsize=(15, 13))
plt.suptitle('Графики категориальных признаков \'market_file\'', fontsize=20)

plt.subplot(3, 2, 1)
market_file['покупательская_активность'].value_counts().plot(kind='pie', autopct='%1.0f%%')

plt.subplot(3, 2, 2)
market_file['тип_сервиса'].value_counts().plot(kind='pie', autopct='%1.0f%%')

plt.subplot(3, 2, 3)
market_file['разрешить_сообщать'].value_counts().plot(kind='pie', autopct='%1.0f%%')

plt.subplot(3, 2, 4)
market_file['популярная_категория'].value_counts().plot(kind='pie', autopct='%1.0f%%');

# %% [markdown]
# Здесь тип сервиса "стандарт" покрывает 71% всех данных, товары для детей самая популярная категория.

# %%
plt.title('Гистограмма распределения времени, проведенного на сайте (мин)')
sns.histplot(data=market_time['минут'], bins=20, kde=True);

# %%
market_time['минут'].plot(kind='box', title='Ящик с усами для времени, проведенного на сайте (мин)');

# %%
market_time['период'].value_counts().plot(kind='pie', autopct='%1.0f%%');

# %%
plt.title('Гистограмма распределения выручки за период')
sns.histplot(data=market_money['выручка'], bins=20, kde=True);

# %%
market_money['выручка'].plot(kind='box', title='Ящик с усами для выручки за период');

# %% [markdown]
# Замечена аномалия, которая может помешать при классификации. Удалим

# %%
lower_bound = market_money['выручка'].mean() - 3 * market_money['выручка'].std()
upper_bound = market_money['выручка'].mean() + 3 * market_money['выручка'].std()

# %%
market_money = market_money[(market_money['выручка'] >= lower_bound) & (market_money['выручка'] <= upper_bound)]

# %%
plt.title('Гистограмма распределения суммы выручки за период')
sns.histplot(data=market_money['выручка'], bins=20, kde=True);

# %%
market_money['выручка'].plot(kind='box', title='Ящик с усами для выручки за период');

# %%
Q1 = market_money['выручка'].quantile(.25)
Q3 = market_money['выручка'].quantile(.75)
IQR = Q3 - Q1

# %%
(1-(market_money.query('выручка < @Q3+1.5*@IQR and выручка > @Q1-1.5*@IQR')['выручка'].count()) / market_money['выручка'].count()) * 100
# Out:
# 4.462682739163892

# %% [markdown]
# Удалим выбросы

# %%
market_money = market_money.query('выручка < @Q3+1.5*@IQR and выручка > @Q1-1.5*@IQR')

# %%
market_money['выручка'].plot(kind='box', title='Ящик с усами для выручки за период');

# %%
market_money['период'].value_counts().plot(kind='pie', autopct='%1.0f%%');

# %%
plt.title('Гистограмма распределения прибыли')
sns.histplot(data=money['прибыль'], bins=20, kde=True);

# %%
money['прибыль'].plot(kind='box', title='Ящик с усами для прибыли');

# %%
Q1 = money['прибыль'].quantile(.25)
Q3 = money['прибыль'].quantile(.75)
IQR = Q3 - Q1

# %%
money = money.query('прибыль < @Q3+1.5*@IQR and прибыль > @Q1-1.5*@IQR')

# %% [markdown]
# Все выбросы удалили. Данные в трех датасетах распределены нормально

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# Объединим таблицы по `id`

# %%
merged_data = pd.merge(market_file, market_money, on=["id"])
merged_data = pd.merge(merged_data, market_time, on=["id"])

# %% [markdown]
# Создадим две сводные таблицы для выручки и времени, затем объединим и их

# %%
pivot_table_revenue = pd.pivot_table(merged_data,
                             values=["выручка"],
                             index="id",
                             columns="период_x",
                             aggfunc={"выручка": "sum"},
                             fill_value=0)

# %%
pivot_table_time = pd.pivot_table(merged_data,
                             values=["минут"],
                             index="id",
                             columns="период_y",
                             aggfunc={"минут": "sum"},
                             fill_value=0)

# %%
pivot_table = pd.merge(pivot_table_revenue, pivot_table_time, on='id')

# %% [markdown]
# Переименуем столбцы для удобства

# %%
pivot_table.columns = [f"{col[1]}_{col[0]}" for col in pivot_table.columns]

# %%
pivot_table.head()
# Out:
#         предыдущий_месяц_выручка  препредыдущий_месяц_выручка  \
# id
# 215349                     10432                         8944
# 215350                     10915                         9652
# 215351                     12316                         9586
# 215352                     11615                         9188
# 215353                      9477                        10248
#
#         текущий_месяц_выручка  предыдущий_месяц_минут  текущий_месяц_минут
# id
# 215349                 9943.2                      36                   30
# 215350                10116.8                      24                   39
# 215351                    0.0                      22                   26
# 215352                11745.0                      24                   33
# 215353                10777.0                      30                   30

# %%
full_data = pd.merge(merged_data, pivot_table, on="id")

# %%
full_data.head()
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215349                 Снизилась     премиум                 да
# 3  215349                 Снизилась     премиум                 да
# 4  215349                 Снизилась     премиум                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.4                     4           819               0.75
# 2                 4.4                     4           819               0.75
# 3                 4.4                     4           819               0.75
# 4                 4.4                     4           819               0.75
#
#   популярная_категория  средний_просмотр_категорий_за_визит  ...  \
# ...

# %% [markdown]
# **Мы видим, что многие строки являются дубликатами, но из-за некоторых столбцов метод не находит их как дубликат. Удалим эти столбцы**

# %%
full_data = full_data.drop(['выручка', 'минут', 'период_x', 'период_y'], axis=1)

# %%
full_data.duplicated().sum()
# Out:
# 6151

# %%
full_data = full_data.drop_duplicates()

# %%
full_data.shape
# Out:
# (1299, 18)

# %% [markdown]
# Выделим клиентов с покупательской активностью не менее 3 месяцев

# %%
full_data = full_data.query('предыдущий_месяц_выручка > 0 and препредыдущий_месяц_выручка > 0 and текущий_месяц_выручка > 0')

# %%
full_data.shape
# Out:
# (1144, 18)

# %% [markdown]
# Мы отсеяли 155 человек

# %% [markdown]
# ## Корелляционный анализ

# %% [markdown]
# Построим матрицу корреляций

# %%
plt.figure(figsize=(11, 9))
sns.heatmap(full_data.drop('id', axis=1).select_dtypes(exclude=object).corr(), annot=True, cmap='cividis', fmt='.2f');

# %% [markdown]
# Судя по матрице, коррелируют выручка в предыдущем и выручка в текущем месяце, а также количество страниц за визит и кол-во минут за предыдущий месяц. Мультиколлинеарность не наблюдается

# %% [markdown]
# ## Пайплайны

# %%
RANDOM_STATE = 42
TEST_SIZE = 0.25

# %%
X_train, X_test, y_train, y_test = train_test_split(
    full_data.drop(['покупательская_активность', 'id'], axis=1),
    full_data['покупательская_активность'],
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    stratify = full_data['покупательская_активность']
)

# %%
y_train.value_counts().plot(kind='bar');

# %% [markdown]
# Разделим категориальные и количественные переменные

# %%
ohe_columns = ['разрешить_сообщать', 'популярная_категория']
ord_columns = ['тип_сервиса']
num_columns = ['маркет_актив_6_мес',
               'маркет_актив_тек_мес',
               'длительность',
               'акционные_покупки',
               'средний_просмотр_категорий_за_визит',
               'неоплаченные_продукты_штук_квартал',
               'ошибка_сервиса',
               'страниц_за_визит',
               'предыдущий_месяц_выручка',
               'препредыдущий_месяц_выручка',
               'текущий_месяц_выручка',
               'предыдущий_месяц_минут',
               'текущий_месяц_минут']

# %%
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
    )

# %%
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['премиум', 'стандарт']
                ],
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ],
    remainder='passthrough'
)

# %% [markdown]
# Итоговый пайплайн:

# %%
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# Перебираем гиперпараметры для каждой модели

# %%
param_grid = [
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__min_samples_split': range(2, 5),
        'models__min_samples_leaf': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },

    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE,
            solver='liblinear',
            penalty='l1'

        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [SVC(random_state=RANDOM_STATE)],
        'models__C': range(1, 5),
        'models__kernel': ['poly', 'rbf']
    }
]

# %% [markdown]
# Выберем метрику `roc_auc`, потому что она подходит для несбалансированных данных. Использовать будем GridSearch, потому что параметров немного.

# %%
start = time.time()
grid_search = GridSearchCV(
    pipe_final,
    param_grid,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1
)
grid_search.fit(X_train, y_train)

print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на тренировочной выборке:', grid_search.best_score_)
finish = time.time() - start
print('Время:', round(finish, 2))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['разрешить_сообщать',
#                                                    'популярная_категория']),
#                                                  ('ord',
# ...

# %% [markdown]
# Самой лучшей моделью оказалась логистическая регрессия с параметрами С=4, penalty='l1', solver='liblinear'. Метрика вышла отличной - 0.91.

# %% [markdown]
# ## Анализ важности признаков

# %% [markdown]
# Вытащим все закодированные признаки и применим к ним shap

# %%
X_train_transformed = pipe_final.named_steps['preprocessor'].fit_transform(X_train)

feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()

X_train_transformed = pd.DataFrame(
    X_train_transformed,
    columns=feature_names
)

X_test_transformed = pd.DataFrame(
    pipe_final.named_steps['preprocessor'].transform(X_test),
    columns=feature_names
)

# %%
explainer = shap.Explainer(grid_search.best_estimator_.named_steps['models'], X_train_transformed)

shap_values = explainer(X_test_transformed)

shap.plots.bar(shap_values, max_display=20)

# %% [markdown]
# Самыми значимыми признаками являются "Популярная категория" и "средний просмотр категорий за визит" . "Маркет актив текущий месяц" и "ошибка сервиса" вообще не имеют вклада.

# %%
plt.figure(figsize=(25, 15))
shap.plots.beeswarm(shap_values, max_display=20)

# %% [markdown]
# Высокие значения признака `Мелкая бытовая техника и электроника` снижают вероятность отнесения заказа к классу 1.

# %%
shap.plots.waterfall(shap_values[1])

# %% [markdown]
# `Мелкая бытовая техника и электроника` "перетягивает" предсказание в сторону класса 0. Отрицательное значение f(x) говорит о том, что наблюдение скорее относится к классу 0.

# %% [markdown]
# ## Сегментация покупателей

# %%
full_data['вероятность'] = np.array(grid_search.best_estimator_.predict_proba(full_data)[:,1])

# %%
full_data = full_data.merge(money, on='id')

# %% [markdown]
# Сегментируем покупателей по высокой вероятности снижения покупательской активности и наиболее высокой прибыльностью.

# %%
profit_quantile = full_data['прибыль'].quantile(0.8)

# %%
high_profit = full_data['прибыль'] > profit_quantile

# %%
customer_segment = full_data[high_profit]

# %%
customer_segment.shape
# Out:
# (225, 20)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(customer_segment, x='прибыль', hue='покупательская_активность', alpha=.7)
plt.title('Распределение прибыли по покупателям')
plt.xlabel('Прибыль')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# Прибыль распределена в основном в районе 4.75 - 5.50

# %%
customer_segment.drop('id', axis=1).describe().T
# Out:
#                                      count          mean          std  \
# маркет_актив_6_мес                   225.0      4.268889     1.019634
# маркет_актив_тек_мес                 225.0      3.906667     0.684784
# длительность                         225.0    609.511111   257.396011
# акционные_покупки                    225.0      0.306400     0.234677
# средний_просмотр_категорий_за_визит  225.0      3.217778     1.376345
# неоплаченные_продукты_штук_квартал   225.0      2.755556     2.010636
# ошибка_сервиса                       225.0      4.208889     1.978887
# страниц_за_визит                     225.0      8.222222     3.969127
# предыдущий_месяц_выручка             225.0   9821.315556  1209.247620
# препредыдущий_месяц_выручка          225.0   9735.626667   709.111670
# текущий_месяц_выручка                225.0  10248.374222  1348.814357
# предыдущий_месяц_минут               225.0     41.080000    11.848101
# ...

# %% [markdown]
# Средняя прибыль у этого сегмента 5.33

# %% [markdown]
# Посмотрим какие категории популярны у этого сегмента

# %%
plt.figure(figsize=(19, 8))
sns.barplot(x=customer_segment['популярная_категория'].value_counts().index,
            y=customer_segment['популярная_категория'].value_counts().values,
            palette="viridis")
plt.xticks(rotation=50)

plt.title('Покупки по категориям для сегмента покупателей')
plt.xlabel('Популярная категория', fontsize=14)
plt.ylabel('Частота', fontsize=14)

plt.show()
# Out:
# <ipython-input-93-3e0f8d2a725b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=customer_segment['популярная_категория'].value_counts().index,

# %% [markdown]
# Самой популярной категорией оказалась "Товары для детей"

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=customer_segment['тип_сервиса'].value_counts().index,
            y=customer_segment['тип_сервиса'].value_counts().values,
            palette='viridis')
plt.title('Распределение типов сервиса')
plt.xlabel('Тип сервиса')
plt.ylabel('Частота')
plt.show()
# Out:
# <ipython-input-103-536c7aa1ca0d>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=customer_segment['тип_сервиса'].value_counts().index,

# %%
fig, axs = plt.subplots(3, 2, figsize=(13, 15))
plt.suptitle('Диаграммы распределения', fontsize=15)

axs[0][0].set_title('Акционные покупки', fontsize=13)
sns.histplot(data=customer_segment, x='акционные_покупки', hue='покупательская_активность', ax=axs[0][0], kde=True, bins=20)

axs[0][1].set_title('Средний просмотр категорий за визит', fontsize=13)
sns.histplot(data=customer_segment, x='средний_просмотр_категорий_за_визит', hue='покупательская_активность', ax=axs[0][1], kde=True, bins=20)

axs[1][0].set_title('Ошибка сервиса', fontsize=13)
sns.histplot(data=customer_segment, x='ошибка_сервиса', hue='покупательская_активность', ax=axs[1][0], kde=True, bins=20)

axs[1][1].set_title('Страниц за визит', fontsize=13)
sns.histplot(data=customer_segment, x='страниц_за_визит', hue='покупательская_активность', ax=axs[1][1], kde=True, bins=20)

axs[2][0].set_title('Маркет актив 6 месяцев', fontsize=13)
sns.histplot(data=customer_segment, x='маркет_актив_6_мес', hue='покупательская_активность', ax=axs[2][0], kde=True, bins=20)

axs[2][1].set_title('Количество неоплаченных продуктов в корзине', fontsize=13)
sns.histplot(data=customer_segment, x='неоплаченные_продукты_штук_квартал', hue='покупательская_активность', ax=axs[2][1], kde=True, bins=20);

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Задачи:**
# - Построение модели, которая предскажет вероятность снижения покупательской активности клиента в следующие 3 месяца;
# - Выделить сегменты покупателей и разработать для них персонализированные предложения.

# %% [markdown]
# **Данные**
#
# Предоставили 4 датасета:
# 1. `market_file` (данные о поведении покупателя на сайте, о коммуникациях с покупателем и его продуктовом поведении);
# 2. `market_money` (данные о выручке, которую получает магазин с покупателя, то есть сколько покупатель всего потратил за период взаимодействия с сайтом);
# 3. `market_time` (данные о времени (в минутах), которое покупатель провёл на сайте в течение периода);
# 4. `money` (данные о среднемесячной прибыли покупателя за последние 3 месяца: какую прибыль получает магазин от продаж каждому покупателю)
#
# Дубликаты были устранены, столбцы переименованы, пропущенных значений не оказалось.

# %% [markdown]
# **Поиск лучшей модели:**
#
# Использовал пайплайны для удобства чтения и работы. Категориалные признаки закодировал с помощью OneHotEncoder() и OrdinalEncoder, количественные с помощью MinMaxScaler() и StandardScaler().

# %% [markdown]
# Обучил четыре модели: `KNeighborsClassifier()`, `DecisionTreeClassifier()`, `LogisticRegression()` и `SVC()`, для каждой подобрал гиперпараметры и посчитал метрику `roc_auc_score()`

# %% [markdown]
# **Лучшая модель:**
#
# Лучшей моделью оказалась логистическая регрессия с гиперпараметрами C=4, penalty='l1', solver='liblinear'

# %% [markdown]
# **Рекомендации:**

# %% [markdown]
# 1. Стоит разработать программу лояльности или предлагать эксклюзивные предложения сегменту покупателей с высокой прибыльностью, дабы "подогревать" их интерес к покупкам. У большей части клиентов доля акционных покупок - 20-30 %;
# 2. Поработать над сайтом. Судя по графику, у некоторых возникает от 4 до 8 ошибок во время посещения магазина, а это может переубедить покупать товар;
# 3. Использование рекомендательных систем на основе предыдущих покупок - у многих клиентов по 1-2 просмотра категорий за визит.
